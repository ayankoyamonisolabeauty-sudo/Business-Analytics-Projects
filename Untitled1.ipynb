# %%
# Run this block of code and enter your name
name = input("Enter your name: ")

print("Name =", name + " Goodluck ")
# Out:
# Enter your name:  Monisola Beauty Ayankoya
# Name = Monisola Beauty Ayankoya Goodluck

# %%
x=20
y=10
x=x+2
x=x-y
print(x)
# Out:
# 12

# %%
x= "i just did python"
print(x)
# Out:
# i just did python
